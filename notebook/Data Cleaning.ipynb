# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ### Coba

# %%
df = pd.read_csv("/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_canggu.csv")
df = df.drop(columns="Unnamed: 0")
df.head()
# Out:
#        location  ...                       date
# 0  Canggu_Beach  ...      Written April 6, 2021
# 1  Canggu_Beach  ...  Written December 18, 2020
# 2  Canggu_Beach  ...  Written November 16, 2020
# 3  Canggu_Beach  ...      Written July 16, 2020
# 4  Canggu_Beach  ...      Written June 25, 2020
#
# [5 rows x 4 columns]

# %%
df['location'].value_counts()
# Out:
# Pranava_Yoga                        100
# Batu_Bolong_Beach                    50
# Pantai_Batu_Mejan_Echo_Beach         50
# Canggu_Beach                         50
# Berawa_Beach                         50
# Nirvana_Strength_Bali                48
# Therapy_Canggu                       48
# Solace_Float                         44
# CrossFit_Wanderlust                  36
# Paradise_Pictures                    34
# Canggu_Scooter_Lessons               24
# Goldust_Beauty_Lounge                20
# Tonic_Day_Spa_and_Botanicals         20
# J_Jireh_Spa_and_Salon                20
# Body_Factory_Bali                    20
# Joga_Yoga_Training                   13
# Taman_Segara_Madu                    13
# Prancak_Beach                        12
# Nelayan_Beach                        11
# Alternative_Beach                     9
# Canggu_Avenue                         4
# Semat_Market                          4
# Fetch_Surf_Training_Center            4
# Pravilo_Bali                          2
# Old_Man_s_Original_Canggu_Market      2
# Name: location, dtype: int64

# %%
int(df['rating'][0][:1])
# Out:
# 4

# %%
df = df.assign(rating_num=df.rating.str[:1])
df['rating_num'] =  pd.to_numeric(df['rating_num'], errors='coerce')

# %%
df
# Out:
#                          location  ... rating_num
# 0                    Canggu_Beach  ...          4
# 1                    Canggu_Beach  ...          5
# 2                    Canggu_Beach  ...          3
# 3                    Canggu_Beach  ...          4
# 4                    Canggu_Beach  ...          5
# ..                            ...  ...        ...
# 683  Tonic_Day_Spa_and_Botanicals  ...          5
# 684  Tonic_Day_Spa_and_Botanicals  ...          5
# 685  Tonic_Day_Spa_and_Botanicals  ...          5
# 686  Tonic_Day_Spa_and_Botanicals  ...          5
# 687  Tonic_Day_Spa_and_Botanicals  ...          5
#
# [688 rows x 5 columns]

# %%
str(df['date'][0][8:])
# Out:
# 'April 6, 2021'

# %%
df['date'] =  df.date.str[8:]
df
# Out:
#                          location  ... rating_num
# 0                    Canggu_Beach  ...          4
# 1                    Canggu_Beach  ...          5
# 2                    Canggu_Beach  ...          3
# 3                    Canggu_Beach  ...          4
# 4                    Canggu_Beach  ...          5
# ..                            ...  ...        ...
# 683  Tonic_Day_Spa_and_Botanicals  ...          5
# 684  Tonic_Day_Spa_and_Botanicals  ...          5
# 685  Tonic_Day_Spa_and_Botanicals  ...          5
# 686  Tonic_Day_Spa_and_Botanicals  ...          5
# 687  Tonic_Day_Spa_and_Botanicals  ...          5
#
# [688 rows x 5 columns]

# %%
df.date[0]
# Out:
# 'April 6, 2021'

# %%
from datetime import datetime

datetime_object = datetime.strptime(df.date[0], '%B %d, %Y')
datetime_object
# Out:
# datetime.datetime(2021, 4, 6, 0, 0)

# %%
df['dates'] = pd.to_datetime(df['date'], format='%B %d, %Y')
df
# Out:
#                          location  ...      dates
# 0                    Canggu_Beach  ... 2021-04-06
# 1                    Canggu_Beach  ... 2020-12-18
# 2                    Canggu_Beach  ... 2020-11-16
# 3                    Canggu_Beach  ... 2020-07-16
# 4                    Canggu_Beach  ... 2020-06-25
# ..                            ...  ...        ...
# 683  Tonic_Day_Spa_and_Botanicals  ... 2019-08-06
# 684  Tonic_Day_Spa_and_Botanicals  ... 2019-08-04
# 685  Tonic_Day_Spa_and_Botanicals  ... 2019-07-31
# 686  Tonic_Day_Spa_and_Botanicals  ... 2019-07-28
# 687  Tonic_Day_Spa_and_Botanicals  ... 2019-07-26
#
# [688 rows x 6 columns]

# %%
df = df[(df['dates']>"2020-01-01")]

# %%
df = df.reset_index()
df
# Out:
#      index                      location  ... rating_num      dates
# 0        0                  Canggu_Beach  ...          4 2021-04-06
# 1        1                  Canggu_Beach  ...          5 2020-12-18
# 2        2                  Canggu_Beach  ...          3 2020-11-16
# 3        3                  Canggu_Beach  ...          4 2020-07-16
# 4        4                  Canggu_Beach  ...          5 2020-06-25
# ..     ...                           ...  ...        ...        ...
# 207    634           CrossFit_Wanderlust  ...          3 2020-02-16
# 208    635           CrossFit_Wanderlust  ...          5 2020-02-10
# 209    668  Tonic_Day_Spa_and_Botanicals  ...          5 2020-03-10
# 210    669  Tonic_Day_Spa_and_Botanicals  ...          5 2020-02-02
# 211    670  Tonic_Day_Spa_and_Botanicals  ...          4 2020-01-29
#
# [212 rows x 7 columns]

# %%
print(df.shape[0])
# Out:
# 212

# %% [markdown]
# ### Cleaning

# %%
links = ['/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_canggu.csv', 
         '/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_jimbaran.csv', 
         '/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_legian.csv',
         '/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_nusa_dua.csv',
         '/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_payangan.csv',
         '/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_tanjung_benoa.csv',
         '/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_ubud.csv',
         '/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_seminyak.csv',
         '/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_kuta.csv',
         '/content/drive/MyDrive/Scrapping Web Tripadvisor/data_csv/tripadvisor_reviews_sanur.csv'
         ]

# %%
count = 0 
for link in links:
  df = pd.read_csv(link)
  df = df.drop(columns="Unnamed: 0")
  df = df.assign(rating_num=df.rating.str[:1])
  df['rating_num'] =  pd.to_numeric(df['rating_num'], errors='coerce')
  df['date'] =  df.date.str[8:]
  df['dates'] = pd.to_datetime(df['date'], format='%B %d, %Y')
  df = df[(df['dates']>"2020-01-01")]
  count += df.shape[0]
  df.reset_index()
  name = '/content/drive/MyDrive/Scrapping Web Tripadvisor/cleaned_data/' + link[78:]
  df.to_csv(name, index=False)

# %%
print(count)
# Out:
# 2253
